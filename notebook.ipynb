# %%
import requests
import json
import pandas as pd
import numpy as np
from dataclasses import dataclass
from datetime import datetime
from typing import List, Optional

# %%
@dataclass
class F1Session:
    """Class representing an F1 session"""
    meeting_key: int
    session_key: int
    location: str
    date_start: str
    date_end: str
    session_type: str
    session_name: str
    country_key: int
    country_code: str
    country_name: str
    circuit_key: int
    circuit_short_name: str
    gmt_offset: str
    year: int
    
    def get_start_datetime(self) -> datetime:
        return datetime.fromisoformat(self.date_start.replace('Z', '+00:00'))
    
    def get_end_datetime(self) -> datetime:
        return datetime.fromisoformat(self.date_end.replace('Z', '+00:00'))
    
    def __str__(self) -> str:
        return f"{self.session_name} - {self.location} ({self.session_type}) - {self.date_start}"

@dataclass
class F1Driver:
    """Class representing an F1 driver"""
    meeting_key: int
    session_key: int
    driver_number: int
    broadcast_name: str
    full_name: str
    name_acronym: str
    team_name: str
    team_colour: str
    first_name: str
    last_name: str
    headshot_url: str
    country_code: Optional[str]
    
    def get_team_colour_hex(self) -> str:
        """Return team colour as a proper hex color code"""
        return f"#{self.team_colour}"
    
    def get_display_name(self) -> str:
        """Return a formatted display name"""
        return f"{self.first_name} {self.last_name}"
    
    def __str__(self) -> str:
        return f"#{self.driver_number} {self.full_name} ({self.name_acronym}) - {self.team_name}"


@dataclass
class F1Lap:
    """Class representing an F1 lap"""
    meeting_key: int
    session_key: int
    driver_number: int
    lap_number: int
    date_start: Optional[str]
    duration_sector_1: Optional[float]
    duration_sector_2: Optional[float]
    duration_sector_3: Optional[float]
    i1_speed: Optional[int]
    i2_speed: Optional[int]
    is_pit_out_lap: bool
    lap_duration: Optional[float]
    segments_sector_1: List[Optional[int]]
    segments_sector_2: List[Optional[int]]
    segments_sector_3: List[Optional[int]]
    st_speed: Optional[int]
    
    def get_start_datetime(self) -> Optional[datetime]:
        """Return the lap start time as a datetime object"""
        if self.date_start:
            return datetime.fromisoformat(self.date_start.replace('Z', '+00:00'))
        return None
    
    def get_total_lap_time(self) -> Optional[float]:
        """Return the total lap duration in seconds"""
        return self.lap_duration
    
    def get_sector_times(self) -> tuple[Optional[float], Optional[float], Optional[float]]:
        """Return sector times as a tuple (sector_1, sector_2, sector_3)"""
        return (self.duration_sector_1, self.duration_sector_2, self.duration_sector_3)
    
    def get_speeds(self) -> tuple[Optional[int], Optional[int], Optional[int]]:
        """Return speeds as a tuple (i1_speed, i2_speed, st_speed)"""
        return (self.i1_speed, self.i2_speed, self.st_speed)
    
    def is_complete_lap(self) -> bool:
        """Check if this is a complete lap with all sector times"""
        return all(time is not None for time in [self.duration_sector_1, self.duration_sector_2, self.duration_sector_3])
    
    def get_average_speed(self) -> Optional[float]:
        """Calculate average speed from available speed measurements"""
        speeds = [speed for speed in [self.i1_speed, self.i2_speed, self.st_speed] if speed is not None]
        return sum(speeds) / len(speeds) if speeds else None
    
    def __str__(self) -> str:
        lap_time_str = f"{self.lap_duration:.3f}s" if self.lap_duration else "N/A"
        return f"Lap #{self.lap_number} - Driver #{self.driver_number} - {lap_time_str}"
   

def get_sessions(year: int = 2025, session_type: str = None, country_name: str = None) -> Optional[List[F1Session]]:
    """
    Fetch F1 sessions for a given year and return as structured data objects
    
    Args:
        year: The year to fetch sessions for (default: 2025)
        
    Returns:
        List of F1Session objects or None if request fails
    """
    link = f"https://api.openf1.org/v1/sessions?"

    adds = f"year={year}"
    if session_type:
        adds += f"&session_type={session_type}"
    if country_name:
        adds += f"&country_name={country_name}"

    res = requests.get(link+adds)
    
    sessions = None
    if res.status_code == 200:
        json_data = res.json()
        sessions = [F1Session(**session_data) for session_data in json_data]
        print(f"Retrieved {len(sessions)} sessions for {year}")
        
    else:
        print(f"Failed to fetch sessions. Status code: {res.status_code}")
    
    return sessions

# %%
sessions = get_sessions(year=2025, session_type='Race')

if sessions:
    print(f"\nTotal sessions: {len(sessions)}")
    
    practice_sessions = [s for s in sessions if s.session_type == 'Practice']
    print(f"Practice sessions: {len(practice_sessions)}")

    qualifying_sessions = [s for s in sessions if s.session_type == 'Qualifying' and s.session_name == 'Qualifying']
    print(f"Qualifying sessions: {len(qualifying_sessions)}")

    race_sessions = [s for s in sessions if s.session_type == 'Race' and s.session_name == 'Race']
    print(f"Race sessions: {len(race_sessions)}")

    sprint_qualifying_sessions = [s for s in sessions if s.session_type == 'Qualifying' and s.session_name == 'Sprint Qualifying']
    print(f"Sprint qualifying sessions: {len(sprint_qualifying_sessions)}")

    sprint_sessions = [s for s in sessions if s.session_type == 'Race' and s.session_name == 'Sprint']
    print(f"Sprint Race sessions: {len(sprint_sessions)}")
    
    bahrain_sessions = [s for s in sessions if s.country_name == 'Bahrain']
    print(f"Bahrain sessions: {len(bahrain_sessions)}")
    
    if sessions:
        first_session = sessions[0]
        print(f"\nFirst session details:")
        print(f"  Location: {first_session.location}")
        print(f"  Session Type: {first_session.session_type}")
        print(f"  Start Time: {first_session.get_start_datetime()}")
        print(f"  End Time: {first_session.get_end_datetime()}")
        print(f"  Circuit: {first_session.circuit_short_name}")
# Out:
# Retrieved 19 sessions for 2025
#
# Total sessions: 19
# Practice sessions: 0
# Qualifying sessions: 0
# Race sessions: 16
# Sprint qualifying sessions: 0
# Sprint Race sessions: 3
# Bahrain sessions: 1
#
# First session details:
#   Location: Melbourne
#   Session Type: Race
#   Start Time: 2025-03-16 04:00:00+00:00
#   End Time: 2025-03-16 06:00:00+00:00
#   Circuit: Melbourne

# %%
get_sessions(session_key=9908)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 get_sessions(session_key=9908)
#
# TypeError: get_sessions() got an unexpected keyword argument 'session_key'

# %%
sessions = get_sessions(year=2025, session_type='Qualifying')
sessions
# Out:
# Retrieved 19 sessions for 2025
# [F1Session(meeting_key=1254, session_key=9689, location='Melbourne', date_start='2025-03-15T05:00:00+00:00', date_end='2025-03-15T06:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=5, country_code='AUS', country_name='Australia', circuit_key=10, circuit_short_name='Melbourne', gmt_offset='11:00:00', year=2025),
#  F1Session(meeting_key=1255, session_key=9989, location='Shanghai', date_start='2025-03-21T07:30:00+00:00', date_end='2025-03-21T08:14:00+00:00', session_type='Qualifying', session_name='Sprint Qualifying', country_key=53, country_code='CHN', country_name='China', circuit_key=49, circuit_short_name='Shanghai', gmt_offset='08:00:00', year=2025),
#  F1Session(meeting_key=1255, session_key=9994, location='Shanghai', date_start='2025-03-22T07:00:00+00:00', date_end='2025-03-22T08:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=53, country_code='CHN', country_name='China', circuit_key=49, circuit_short_name='Shanghai', gmt_offset='08:00:00', year=2025),
#  F1Session(meeting_key=1256, session_key=10002, location='Suzuka', date_start='2025-04-05T06:00:00+00:00', date_end='2025-04-05T07:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=4, country_code='JPN', country_name='Japan', circuit_key=46, circuit_short_name='Suzuka', gmt_offset='09:00:00', year=2025),
#  F1Session(meeting_key=1257, session_key=10010, location='Sakhir', date_start='2025-04-12T16:00:00+00:00', date_end='2025-04-12T17:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=36, country_code='BRN', country_name='Bahrain', circuit_key=63, circuit_short_name='Sakhir', gmt_offset='03:00:00', year=2025),
#  F1Session(meeting_key=1258, session_key=10018, location='Jeddah', date_start='2025-04-19T17:00:00+00:00', date_end='2025-04-19T18:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=153, country_code='KSA', country_name='Saudi Arabia', circuit_key=149, circuit_short_name='Jeddah', gmt_offset='03:00:00', year=2025),
#  F1Session(meeting_key=1259, session_key=10024, location='Miami', date_start='2025-05-02T20:30:00+00:00', date_end='2025-05-02T21:14:00+00:00', session_type='Qualifying', session_name='Sprint Qualifying', country_key=19, country_code='USA', country_name='United States', circuit_key=151, circuit_short_name='Miami', gmt_offset='-04:00:00', year=2025),
#  F1Session(meeting_key=1259, session_key=10029, location='Miami', date_start='2025-05-03T20:00:00+00:00', date_end='2025-05-03T21:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=19, country_code='USA', country_name='United States', circuit_key=151, circuit_short_name='Miami', gmt_offset='-04:00:00', year=2025),
#  F1Session(meeting_key=1260, session_key=9983, location='Imola', date_start='2025-05-17T14:00:00+00:00', date_end='2025-05-17T15:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=13, country_code='ITA', country_name='Italy', circuit_key=6, circuit_short_name='Imola', gmt_offset='02:00:00', year=2025),
#  F1Session(meeting_key=1261, session_key=9975, location='Monaco', date_start='2025-05-24T14:00:00+00:00', date_end='2025-05-24T15:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=114, country_code='MON', country_name='Monaco', circuit_key=22, circuit_short_name='Monte Carlo', gmt_offset='02:00:00', year=2025),
#  F1Session(meeting_key=1262, session_key=9967, location='Barcelona', date_start='2025-05-31T14:00:00+00:00', date_end='2025-05-31T15:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=1, country_code='ESP', country_name='Spain', circuit_key=15, circuit_short_name='Catalunya', gmt_offset='02:00:00', year=2025),
#  F1Session(meeting_key=1263, session_key=9959, location='Montréal', date_start='2025-06-14T20:00:00+00:00', date_end='2025-06-14T21:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=46, country_code='CAN', country_name='Canada', circuit_key=23, circuit_short_name='Montreal', gmt_offset='-04:00:00', year=2025),
#  F1Session(meeting_key=1264, session_key=9951, location='Spielberg', date_start='2025-06-28T14:00:00+00:00', date_end='2025-06-28T15:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=17, country_code='AUT', country_name='Austria', circuit_key=19, circuit_short_name='Spielberg', gmt_offset='02:00:00', year=2025),
#  F1Session(meeting_key=1277, session_key=9943, location='Silverstone', date_start='2025-07-05T14:00:00+00:00', date_end='2025-07-05T15:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=2, country_code='GBR', country_name='United Kingdom', circuit_key=2, circuit_short_name='Silverstone', gmt_offset='01:00:00', year=2025),
#  F1Session(meeting_key=1265, session_key=9930, location='Spa-Francorchamps', date_start='2025-07-25T14:30:00+00:00', date_end='2025-07-25T15:14:00+00:00', session_type='Qualifying', session_name='Sprint Qualifying', country_key=16, country_code='BEL', country_name='Belgium', circuit_key=7, circuit_short_name='Spa-Francorchamps', gmt_offset='02:00:00', year=2025),
#  F1Session(meeting_key=1265, session_key=9935, location='Spa-Francorchamps', date_start='2025-07-26T14:00:00+00:00', date_end='2025-07-26T15:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=16, country_code='BEL', country_name='Belgium', circuit_key=7, circuit_short_name='Spa-Francorchamps', gmt_offset='02:00:00', year=2025),
#  F1Session(meeting_key=1266, session_key=9924, location='Budapest', date_start='2025-08-02T14:00:00+00:00', date_end='2025-08-02T15:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=14, country_code='HUN', country_name='Hungary', circuit_key=4, circuit_short_name='Hungaroring', gmt_offset='02:00:00', year=2025),
#  F1Session(meeting_key=1267, session_key=9916, location='Zandvoort', date_start='2025-08-30T13:00:00+00:00', date_end='2025-08-30T14:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=133, country_code='NED', country_name='Netherlands', circuit_key=55, circuit_short_name='Zandvoort', gmt_offset='02:00:00', year=2025),
#  F1Session(meeting_key=1268, session_key=9908, location='Monza', date_start='2025-09-06T14:00:00+00:00', date_end='2025-09-06T15:00:00+00:00', session_type='Qualifying', session_name='Qualifying', country_key=13, country_code='ITA', country_name='Italy', circuit_key=39, circuit_short_name='Monza', gmt_offset='02:00:00', year=2025)]

# %%
def get_drivers(session_key: str = 'latest') -> Optional[List[F1Driver]]:
    """
    Fetch F1 Drivers for a given session key and return as structured data objects
    
    Args:
        session_key: The session key of the race or session (default: 'latest')
        
    Returns:
        List of F1Driver objects or None if request fails
    """
    link = f"https://api.openf1.org/v1/drivers?session_key={session_key}"

    res = requests.get(link)
    
    drivers = None
    if res.status_code == 200:
        json_data = res.json()
        # Convert JSON data to F1Driver objects
        drivers = [F1Driver(**driver_data) for driver_data in json_data]
        print(f"Retrieved {len(drivers)} drivers for session {session_key}")
        for driver in drivers[:3]:  # Print first 3 drivers
            print(f"  - {driver}")
        if len(drivers) > 3:
            print(f"  ... and {len(drivers) - 3} more drivers")
    else:
        print(f"Failed to fetch drivers. Status code: {res.status_code}")
    
    return drivers

# %%
# Example usage of the new F1Driver data type
drivers = get_drivers()

if drivers:
    print(f"\nTotal drivers: {len(drivers)}")
    
    # Example: Get all Red Bull Racing drivers
    red_bull_drivers = [d for d in drivers if d.team_name == 'Red Bull Racing']
    print(f"Red Bull Racing drivers: {len(red_bull_drivers)}")
    for driver in red_bull_drivers:
        print(f"  - {driver}")
    
    # Example: Get drivers by number range
    top_ten_drivers = [d for d in drivers if d.driver_number <= 10]
    print(f"\nDrivers with numbers 1-10: {len(top_ten_drivers)}")
    
    # Example: Access individual driver properties
    if drivers:
        first_driver = drivers[0]
        print(f"\nFirst driver details:")
        print(f"  Name: {first_driver.get_display_name()}")
        print(f"  Number: #{first_driver.driver_number}")
        print(f"  Team: {first_driver.team_name}")
        print(f"  Team Color: {first_driver.get_team_colour_hex()}")
        print(f"  Acronym: {first_driver.name_acronym}")
        print(f"  Headshot URL: {first_driver.headshot_url}")
# Out:
# Retrieved 20 drivers for session latest
#   - #1 Max VERSTAPPEN (VER) - Red Bull Racing
#   - #4 Lando NORRIS (NOR) - McLaren
#   - #5 Gabriel BORTOLETO (BOR) - Kick Sauber
#   ... and 17 more drivers
#
# Total drivers: 20
# Red Bull Racing drivers: 2
#   - #1 Max VERSTAPPEN (VER) - Red Bull Racing
#   - #22 Yuki TSUNODA (TSU) - Red Bull Racing
#
# Drivers with numbers 1-10: 5
#
# First driver details:
#   Name: Max Verstappen
#   Number: #1
#   Team: Red Bull Racing
#   Team Color: #4781D7
#   Acronym: VER
#   Headshot URL: https://media.formula1.com/d_driver_fallback_image.png/content/dam/fom-website/drivers/M/MAXVER01_Max_Verstappen/maxver01.png.transform/1col/image.png

# %%
# drivers

# %%
def get_laps(session_key: str = 'latest', driver_number: int = None) -> Optional[List[F1Lap]]:
    """
    Fetch F1 laps for a given session key and return as structured data objects
    
    Args:
        session_key: The session key of the race or session (default: 'latest')
        driver_number: Optional driver number to filter laps (default: None for all drivers)
        
    Returns:
        List of F1Lap objects or None if request fails
    """
    link = f"https://api.openf1.org/v1/laps?session_key={session_key}"
    
    if driver_number:
        link += f"&driver_number={driver_number}"

    res = requests.get(link)
    
    laps = None
    if res.status_code == 200:
        json_data = res.json()
        # Convert JSON data to F1Lap objects
        laps = [F1Lap(**lap_data) for lap_data in json_data]
        print(f"Retrieved {len(laps)} laps for session {session_key}")
        for lap in laps[:3]:  # Print first 3 laps
            print(f"  - {lap}")
        if len(laps) > 3:
            print(f"  ... and {len(laps) - 3} more laps")
    else:
        print(f"Failed to fetch laps. Status code: {res.status_code}")
    
    return laps

# %%
laps = get_laps()
# Out:
# Retrieved 976 laps for session latest
#   - Lap #1 - Driver #27 - N/A
#   - Lap #1 - Driver #1 - N/A
#   - Lap #1 - Driver #4 - N/A
#   ... and 973 more laps

# %%
laps
# Out:
# [F1Lap(meeting_key=1268, session_key=9912, driver_number=27, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=None, duration_sector_3=None, i1_speed=None, i2_speed=None, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 0, 0, 0, 0, 0], segments_sector_2=[0, 0, 0, 0, 0, 0, 0], segments_sector_3=[0, 0, 0, 0, 0, 0, 0, 0, 0], st_speed=None),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=1, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=29.088, duration_sector_3=28.517, i1_speed=321, i2_speed=309, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2051, 2049, 2049, 2051, 2051, 2049, 2049], segments_sector_3=[2051, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2051], st_speed=284),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=4, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=29.911, duration_sector_3=27.903, i1_speed=330, i2_speed=312, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2051, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2051, 2049, 2049, 2051, 2051, 2049, 2051, 2051], st_speed=267),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=81, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=30.023, duration_sector_3=28.116, i1_speed=322, i2_speed=318, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=287),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=16, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=30.558, duration_sector_3=28.013, i1_speed=339, i2_speed=318, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2051, 2049], segments_sector_3=[2049, 2049, 2049, 2051, 2049, 2049, 2051, 2051, 2051], st_speed=292),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=63, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=30.234, duration_sector_3=28.243, i1_speed=328, i2_speed=319, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=286),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=14, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=30.38, duration_sector_3=28.63, i1_speed=340, i2_speed=317, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=298),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=5, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=30.99, duration_sector_3=28.607, i1_speed=340, i2_speed=320, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=294),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=44, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=31.219, duration_sector_3=28.299, i1_speed=339, i2_speed=313, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2051, 2049, 2049, 2049, 2049, 2051, 2051], st_speed=298),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=22, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=31.382, duration_sector_3=28.985, i1_speed=337, i2_speed=326, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=257),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=12, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=31.496, duration_sector_3=28.871, i1_speed=333, i2_speed=314, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=266),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=87, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=31.002, duration_sector_3=29.046, i1_speed=320, i2_speed=324, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=271),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=55, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=31.052, duration_sector_3=29.14, i1_speed=331, i2_speed=315, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=278),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=23, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=31.206, duration_sector_3=29.271, i1_speed=323, i2_speed=330, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=272),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=31, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=31.35, duration_sector_3=29.494, i1_speed=327, i2_speed=334, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2051], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=260),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=30, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=31.422, duration_sector_3=29.496, i1_speed=342, i2_speed=333, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2051, 2049, 2049, 2051, 2051], segments_sector_2=[2049, 2049, 2051, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=291),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=18, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=32.185, duration_sector_3=29.244, i1_speed=303, i2_speed=316, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=268),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=43, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=31.813, duration_sector_3=29.284, i1_speed=321, i2_speed=320, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[2048, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=279),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=6, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=29.816, duration_sector_3=28.549, i1_speed=328, i2_speed=324, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[None, 2064, 2049, 2051, 2049, 2049], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=283),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=10, lap_number=1, date_start=None, duration_sector_1=None, duration_sector_2=29.724, duration_sector_3=28.616, i1_speed=328, i2_speed=321, is_pit_out_lap=False, lap_duration=None, segments_sector_1=[None, 2064, 2049, 2049, 2049, 2049], segments_sector_2=[2049, 2051, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=261),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=1, lap_number=2, date_start='2025-09-07T13:05:02.302000+00:00', duration_sector_1=28.457, duration_sector_2=28.843, duration_sector_3=27.559, i1_speed=314, i2_speed=326, is_pit_out_lap=False, lap_duration=84.859, segments_sector_1=[2049, 2049, 2048, 2049, 2049, 2049], segments_sector_2=[2048, 2049, 2049, 2048, 2049, 2049, 2049], segments_sector_3=[2051, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=309),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=4, lap_number=2, date_start='2025-09-07T13:05:02.727000+00:00', duration_sector_1=27.675, duration_sector_2=28.557, duration_sector_3=27.657, i1_speed=311, i2_speed=311, is_pit_out_lap=False, lap_duration=83.889, segments_sector_1=[2049, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2051, 2051, 2051, 2051, 2049, 2048], segments_sector_3=[2049, 2051, 2048, 2049, 2051, 2051, 2048, 2048, 2048], st_speed=322),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=81, lap_number=2, date_start='2025-09-07T13:05:03.127000+00:00', duration_sector_1=27.817, duration_sector_2=29.686, duration_sector_3=28.256, i1_speed=336, i2_speed=336, is_pit_out_lap=False, lap_duration=85.759, segments_sector_1=[2049, 2049, 2051, 2049, 2048, 2049], segments_sector_2=[2048, 2049, 2049, 2048, 2049, 2049, 2049], segments_sector_3=[2049, 2048, 2049, 2049, 2048, 2048, 2049, 2049, 2049], st_speed=340),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=16, lap_number=2, date_start='2025-09-07T13:05:03.507000+00:00', duration_sector_1=27.47, duration_sector_2=29.358, duration_sector_3=28.35, i1_speed=325, i2_speed=331, is_pit_out_lap=False, lap_duration=85.178, segments_sector_1=[2051, 2051, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=352),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=63, lap_number=2, date_start='2025-09-07T13:05:04.066000+00:00', duration_sector_1=27.677, duration_sector_2=29.339, duration_sector_3=28.293, i1_speed=321, i2_speed=334, is_pit_out_lap=False, lap_duration=85.309, segments_sector_1=[2049, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2048, 2048, 2048, 2048, 2049, 2049, 2049, 2049], st_speed=338),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=14, lap_number=2, date_start='2025-09-07T13:05:04.801000+00:00', duration_sector_1=28.102, duration_sector_2=29.35, duration_sector_3=28.474, i1_speed=321, i2_speed=337, is_pit_out_lap=False, lap_duration=85.926, segments_sector_1=[2049, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2048, 2048, 2049, 2048, 2049, 2049], st_speed=322),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=5, lap_number=2, date_start='2025-09-07T13:05:05.231000+00:00', duration_sector_1=27.588, duration_sector_2=28.937, duration_sector_3=28.298, i1_speed=319, i2_speed=339, is_pit_out_lap=False, lap_duration=84.823, segments_sector_1=[2049, 2049, 2048, 2049, 2049, 2048], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2048, 2048, 2049, 2049, 2048, 2048, 2049, 2048], st_speed=342),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=44, lap_number=2, date_start='2025-09-07T13:05:05.607000+00:00', duration_sector_1=27.501, duration_sector_2=29.625, duration_sector_3=28.376, i1_speed=330, i2_speed=339, is_pit_out_lap=False, lap_duration=85.502, segments_sector_1=[2049, 2049, 2049, 2051, 2048, 2048], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048], st_speed=337),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=22, lap_number=2, date_start='2025-09-07T13:05:06.572000+00:00', duration_sector_1=27.805, duration_sector_2=29.267, duration_sector_3=28.277, i1_speed=327, i2_speed=342, is_pit_out_lap=False, lap_duration=85.349, segments_sector_1=[2049, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2048, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=322),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=12, lap_number=2, date_start='2025-09-07T13:05:06.884000+00:00', duration_sector_1=27.625, duration_sector_2=29.637, duration_sector_3=28.191, i1_speed=326, i2_speed=338, is_pit_out_lap=False, lap_duration=85.453, segments_sector_1=[2049, 2049, 2049, 2049, 2049, 2048], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=342),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=87, lap_number=2, date_start='2025-09-07T13:05:07.166000+00:00', duration_sector_1=27.91, duration_sector_2=29.363, duration_sector_3=28.398, i1_speed=None, i2_speed=342, is_pit_out_lap=False, lap_duration=85.671, segments_sector_1=[2049, 2049, 2049, 2049, 2048, 2049], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2049, 2051], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2048, 2048, 2049, 2048], st_speed=325),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=55, lap_number=2, date_start='2025-09-07T13:05:07.650000+00:00', duration_sector_1=27.813, duration_sector_2=29.35, duration_sector_3=28.465, i1_speed=326, i2_speed=341, is_pit_out_lap=False, lap_duration=85.628, segments_sector_1=[2049, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2048, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=328),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=23, lap_number=2, date_start='2025-09-07T13:05:08.025000+00:00', duration_sector_1=27.809, duration_sector_2=29.38, duration_sector_3=28.573, i1_speed=322, i2_speed=342, is_pit_out_lap=False, lap_duration=85.762, segments_sector_1=[2049, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2048, 2049, 2049, 2048, 2049, 2049], st_speed=330),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=31, lap_number=2, date_start='2025-09-07T13:05:08.431000+00:00', duration_sector_1=28.398, duration_sector_2=28.92, duration_sector_3=28.579, i1_speed=329, i2_speed=340, is_pit_out_lap=False, lap_duration=85.897, segments_sector_1=[2049, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2048, 2049, 2049, 2048, 2048, 2048, 2048], st_speed=315),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=30, lap_number=2, date_start='2025-09-07T13:05:08.681000+00:00', duration_sector_1=28.289, duration_sector_2=29.65, duration_sector_3=28.312, i1_speed=324, i2_speed=339, is_pit_out_lap=False, lap_duration=86.251, segments_sector_1=[2049, 2049, 2049, 2048, 2048, 2048], segments_sector_2=[2049, 2049, 2048, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2048, 2049, 2049, 2049, 2048, 2049, 2048], st_speed=331),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=18, lap_number=2, date_start='2025-09-07T13:05:09.150000+00:00', duration_sector_1=27.702, duration_sector_2=30.488, duration_sector_3=28.316, i1_speed=333, i2_speed=338, is_pit_out_lap=False, lap_duration=86.506, segments_sector_1=[2049, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2049, None, None, 2049, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2048, 2048], st_speed=321),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=43, lap_number=2, date_start='2025-09-07T13:05:09.541000+00:00', duration_sector_1=28.152, duration_sector_2=30.192, duration_sector_3=28.431, i1_speed=317, i2_speed=335, is_pit_out_lap=False, lap_duration=86.775, segments_sector_1=[2049, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2049, 2049, 2048, 2048, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2048, 2049, 2049, 2049, 2049, 2048, 2049], st_speed=308),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=6, lap_number=2, date_start='2025-09-07T13:05:10.082000+00:00', duration_sector_1=28.158, duration_sector_2=30.04, duration_sector_3=28.534, i1_speed=322, i2_speed=332, is_pit_out_lap=False, lap_duration=86.732, segments_sector_1=[2049, 2049, 2049, 2048, 2049, 2048], segments_sector_2=[2048, 2049, 2049, 2048, 2048, 2051, 2049], segments_sector_3=[2049, 2048, 2048, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=328),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=10, lap_number=2, date_start='2025-09-07T13:05:10.852000+00:00', duration_sector_1=28.186, duration_sector_2=29.769, duration_sector_3=28.608, i1_speed=315, i2_speed=333, is_pit_out_lap=False, lap_duration=86.563, segments_sector_1=[2049, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2049, 2049, 2048, 2049, 2049], segments_sector_3=[2049, 2048, 2048, 2048, 2049, 2049, 2049, 2049, 2049], st_speed=313),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=4, lap_number=3, date_start='2025-09-07T13:06:26.418000+00:00', duration_sector_1=27.624, duration_sector_2=28.43, duration_sector_3=27.62, i1_speed=307, i2_speed=311, is_pit_out_lap=False, lap_duration=83.674, segments_sector_1=[2048, 2048, 2048, 2049, 2049, 2048], segments_sector_2=[2048, 2051, 2051, 2051, 2051, 2049, 2048], segments_sector_3=[2049, 2051, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=329),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=1, lap_number=3, date_start='2025-09-07T13:06:27.253000+00:00', duration_sector_1=27.212, duration_sector_2=28.713, duration_sector_3=27.587, i1_speed=320, i2_speed=329, is_pit_out_lap=False, lap_duration=83.512, segments_sector_1=[None, 2049, 2049, 2049, 2049, 2049], segments_sector_2=[2048, 2049, 2049, 2048, 2048, 2049, 2049], segments_sector_3=[2048, 2049, 2049, 2049, 2048, 2048, 2049, 2051], st_speed=350),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=16, lap_number=3, date_start='2025-09-07T13:06:28.646000+00:00', duration_sector_1=27.995, duration_sector_2=29.025, duration_sector_3=27.945, i1_speed=315, i2_speed=318, is_pit_out_lap=False, lap_duration=84.965, segments_sector_1=[2048, 2048, 2049, 2048, 2048, 2048], segments_sector_2=[2049, 2049, 2049, 2049, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2049, 2049, 2048, 2048, 2048], st_speed=336),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=81, lap_number=3, date_start='2025-09-07T13:06:28.849000+00:00', duration_sector_1=28.424, duration_sector_2=28.647, duration_sector_3=28.046, i1_speed=314, i2_speed=328, is_pit_out_lap=False, lap_duration=85.117, segments_sector_1=[None, 2049, 2048, 2048, 2048, 2048], segments_sector_2=[2049, 2049, 2049, 2049, 2049, 2049, 2048], segments_sector_3=[2048, 2048, 2049, 2048, 2048, 2048, 2049, 2049, 2049], st_speed=347),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=63, lap_number=3, date_start='2025-09-07T13:06:29.443000+00:00', duration_sector_1=28.305, duration_sector_2=29.054, duration_sector_3=27.987, i1_speed=325, i2_speed=329, is_pit_out_lap=False, lap_duration=85.346, segments_sector_1=[None, 2049, 2048, 2048, 2048, 2048], segments_sector_2=[2049, 2048, 2049, 2049, 2049, 2048, 2048], segments_sector_3=[2049, 2048, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=337),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=5, lap_number=3, date_start='2025-09-07T13:06:30.115000+00:00', duration_sector_1=27.553, duration_sector_2=29.583, duration_sector_3=28.218, i1_speed=323, i2_speed=341, is_pit_out_lap=False, lap_duration=85.354, segments_sector_1=[2049, 2049, 2049, 2048, 2049, 2048], segments_sector_2=[2048, 2048, 2048, 2049, 2048, 2049, 2049], segments_sector_3=[2048, 2048, 2049, 2049, 2049, 2049, 2048, 2049, 2048], st_speed=347),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=14, lap_number=3, date_start='2025-09-07T13:06:30.896000+00:00', duration_sector_1=27.618, duration_sector_2=29.576, duration_sector_3=28.209, i1_speed=318, i2_speed=333, is_pit_out_lap=False, lap_duration=85.403, segments_sector_1=[None, 2049, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2048, 2048, 2048, 2048], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=349),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=44, lap_number=3, date_start='2025-09-07T13:06:31.318000+00:00', duration_sector_1=27.463, duration_sector_2=29.717, duration_sector_3=28.306, i1_speed=325, i2_speed=339, is_pit_out_lap=False, lap_duration=85.486, segments_sector_1=[2051, 2051, 2049, 2048, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2048, 2048, 2049, 2048], segments_sector_3=[2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=343),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=22, lap_number=3, date_start='2025-09-07T13:06:31.849000+00:00', duration_sector_1=27.68, duration_sector_2=29.478, duration_sector_3=28.368, i1_speed=316, i2_speed=341, is_pit_out_lap=False, lap_duration=85.526, segments_sector_1=[None, 2049, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2049, 2048, 2048, 2048, 2049], segments_sector_3=[2049, 2048, 2049, 2048, 2049, 2049, 2049, 2049, 2049], st_speed=339),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=12, lap_number=3, date_start='2025-09-07T13:06:32.381000+00:00', duration_sector_1=27.462, duration_sector_2=29.648, duration_sector_3=28.351, i1_speed=312, i2_speed=338, is_pit_out_lap=False, lap_duration=85.461, segments_sector_1=[None, 2049, 2048, 2051, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2049, 2049], segments_sector_3=[2048, 2048, 2049, 2048, 2048, 2048, 2048, 2049, 2048], st_speed=336),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=87, lap_number=3, date_start='2025-09-07T13:06:32.849000+00:00', duration_sector_1=27.504, duration_sector_2=29.406, duration_sector_3=28.51, i1_speed=318, i2_speed=343, is_pit_out_lap=False, lap_duration=85.42, segments_sector_1=[None, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2049, 2049, 2048, 2049, 2051], segments_sector_3=[2049, 2048, 2049, 2049, 2048, 2048, 2048, 2048, 2048], st_speed=345),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=55, lap_number=3, date_start='2025-09-07T13:06:33.334000+00:00', duration_sector_1=27.502, duration_sector_2=29.5, duration_sector_3=28.412, i1_speed=321, i2_speed=335, is_pit_out_lap=False, lap_duration=85.414, segments_sector_1=[None, 2049, 2049, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2049, 2048, 2048, 2049, 2048], segments_sector_3=[2049, 2049, 2049, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=351),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=23, lap_number=3, date_start='2025-09-07T13:06:33.881000+00:00', duration_sector_1=27.41, duration_sector_2=29.424, duration_sector_3=28.404, i1_speed=319, i2_speed=340, is_pit_out_lap=False, lap_duration=85.238, segments_sector_1=[None, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2048, 2048, 2048, 2049, 2048], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2049], st_speed=352),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=31, lap_number=3, date_start='2025-09-07T13:06:34.271000+00:00', duration_sector_1=27.355, duration_sector_2=29.41, duration_sector_3=28.39, i1_speed=318, i2_speed=340, is_pit_out_lap=False, lap_duration=85.155, segments_sector_1=[None, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2048, 2048, 2051, 2049], segments_sector_3=[2048, 2049, 2049, 2049, 2049, 2049, 2049, 2049, 2049], st_speed=338),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=30, lap_number=3, date_start='2025-09-07T13:06:35.037000+00:00', duration_sector_1=27.394, duration_sector_2=29.194, duration_sector_3=28.354, i1_speed=317, i2_speed=344, is_pit_out_lap=False, lap_duration=84.942, segments_sector_1=[None, 2049, 2048, 2049, 2048, 2048], segments_sector_2=[2049, 2049, 2049, 2049, 2048, 2048, 2049], segments_sector_3=[2049, 2048, 2048, 2048, 2048, 2048, 2049, 2049, 2049], st_speed=343),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=18, lap_number=3, date_start='2025-09-07T13:06:35.693000+00:00', duration_sector_1=27.603, duration_sector_2=29.126, duration_sector_3=28.335, i1_speed=313, i2_speed=335, is_pit_out_lap=False, lap_duration=85.064, segments_sector_1=[None, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2049, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2049, 2049, 2049, 2048, 2048], st_speed=338),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=43, lap_number=3, date_start='2025-09-07T13:06:36.318000+00:00', duration_sector_1=27.648, duration_sector_2=29.365, duration_sector_3=28.333, i1_speed=309, i2_speed=329, is_pit_out_lap=False, lap_duration=85.346, segments_sector_1=[None, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2049, 2048, 2048, 2049, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2049, 2048, 2049, 2048, 2048, 2048, 2048], st_speed=339),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=6, lap_number=3, date_start='2025-09-07T13:06:36.803000+00:00', duration_sector_1=27.609, duration_sector_2=29.65, duration_sector_3=28.208, i1_speed=316, i2_speed=342, is_pit_out_lap=False, lap_duration=85.467, segments_sector_1=[None, 2049, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2048, 2048, 2048, 2048, 2049], segments_sector_3=[2049, 2049, 2049, 2051, 2049, 2049, 2049, 2048, 2049], st_speed=323),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=10, lap_number=3, date_start='2025-09-07T13:06:37.443000+00:00', duration_sector_1=27.716, duration_sector_2=29.646, duration_sector_3=28.144, i1_speed=312, i2_speed=330, is_pit_out_lap=False, lap_duration=85.506, segments_sector_1=[None, 2049, 2048, 2049, 2049, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2048, 2048, 2048], segments_sector_3=[2049, 2049, 2049, 2048, 2049, 2049, 2049, 2049, 2049], st_speed=335),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=4, lap_number=4, date_start='2025-09-07T13:07:50.319000+00:00', duration_sector_1=28.346, duration_sector_2=28.762, duration_sector_3=27.711, i1_speed=305, i2_speed=321, is_pit_out_lap=False, lap_duration=84.819, segments_sector_1=[None, 2048, 2049, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2049, 2049], segments_sector_3=[2049, 2048, 2049, 2049, 2048, 2048, 2048, 2049, 2048], st_speed=322),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=1, lap_number=4, date_start='2025-09-07T13:07:50.554000+00:00', duration_sector_1=27.375, duration_sector_2=28.455, duration_sector_3=27.432, i1_speed=312, i2_speed=312, is_pit_out_lap=False, lap_duration=83.262, segments_sector_1=[None, 2049, 2051, 2048, 2048, 2048], segments_sector_2=[2048, 2051, 2049, 2049, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2051, 2049, 2048, 2048, 2048], st_speed=352),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=16, lap_number=4, date_start='2025-09-07T13:07:53.632000+00:00', duration_sector_1=27.653, duration_sector_2=29.02, duration_sector_3=27.852, i1_speed=308, i2_speed=318, is_pit_out_lap=False, lap_duration=84.525, segments_sector_1=[None, 2048, 2049, 2049, 2048, 2048], segments_sector_2=[2049, 2048, 2048, 2048, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2048, 2049, 2048, 2049, 2048], st_speed=323),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=81, lap_number=4, date_start='2025-09-07T13:07:54.069000+00:00', duration_sector_1=27.516, duration_sector_2=29.12, duration_sector_3=27.931, i1_speed=316, i2_speed=325, is_pit_out_lap=False, lap_duration=84.567, segments_sector_1=[None, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2049, 2048, 2049, 2048, 2048, 2049, 2049, 2049, 2049], st_speed=337),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=63, lap_number=4, date_start='2025-09-07T13:07:54.757000+00:00', duration_sector_1=27.405, duration_sector_2=29.093, duration_sector_3=28.015, i1_speed=315, i2_speed=329, is_pit_out_lap=False, lap_duration=84.513, segments_sector_1=[None, 2049, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2049, 2048, 2048, 2049, 2049, 2049, 2049], st_speed=340),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=5, lap_number=4, date_start='2025-09-07T13:07:55.569000+00:00', duration_sector_1=27.484, duration_sector_2=29.009, duration_sector_3=28.251, i1_speed=315, i2_speed=334, is_pit_out_lap=False, lap_duration=84.744, segments_sector_1=[2048, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2048, 2049, 2048, 2048], segments_sector_3=[2049, 2049, 2049, 2048, 2048, 2048, 2048, 2051, 2048], st_speed=334),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=14, lap_number=4, date_start='2025-09-07T13:07:56.241000+00:00', duration_sector_1=27.621, duration_sector_2=28.963, duration_sector_3=28.277, i1_speed=309, i2_speed=327, is_pit_out_lap=False, lap_duration=84.861, segments_sector_1=[None, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2049, 2048, 2048, 2048, 2048, 2048, 2049], st_speed=336),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=44, lap_number=4, date_start='2025-09-07T13:07:56.757000+00:00', duration_sector_1=27.415, duration_sector_2=29.339, duration_sector_3=27.99, i1_speed=None, i2_speed=337, is_pit_out_lap=False, lap_duration=84.744, segments_sector_1=[2048, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2048, 2048], segments_sector_3=[2049, 2049, 2049, 2048, 2049, 2048, 2048, 2051, 2051], st_speed=336),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=22, lap_number=4, date_start='2025-09-07T13:07:57.304000+00:00', duration_sector_1=27.607, duration_sector_2=29.192, duration_sector_3=28.072, i1_speed=None, i2_speed=338, is_pit_out_lap=False, lap_duration=84.871, segments_sector_1=[None, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2048, 2048, 2048], segments_sector_3=[2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2049], st_speed=330),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=12, lap_number=4, date_start='2025-09-07T13:07:57.725000+00:00', duration_sector_1=27.359, duration_sector_2=29.466, duration_sector_3=28.016, i1_speed=320, i2_speed=338, is_pit_out_lap=False, lap_duration=84.841, segments_sector_1=[None, 2049, 2048, 2048, 2049, 2048], segments_sector_2=[2048, 2049, 2049, 2048, 2049, 2049, 2049], segments_sector_3=[2049, 2049, 2049, 2048, 2049, 2049, 2049, 2049, 2049], st_speed=342),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=87, lap_number=4, date_start='2025-09-07T13:07:58.241000+00:00', duration_sector_1=27.563, duration_sector_2=29.162, duration_sector_3=28.16, i1_speed=320, i2_speed=344, is_pit_out_lap=False, lap_duration=84.885, segments_sector_1=[None, 2051, 2048, 2049, 2048, 2048], segments_sector_2=[2049, 2048, 2049, 2048, 2049, 2049, 2051], segments_sector_3=[2048, 2049, 2049, 2048, 2049, 2048, 2049, 2049, 2048], st_speed=339),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=55, lap_number=4, date_start='2025-09-07T13:07:58.710000+00:00', duration_sector_1=27.578, duration_sector_2=29.394, duration_sector_3=28.232, i1_speed=315, i2_speed=334, is_pit_out_lap=False, lap_duration=85.204, segments_sector_1=[2048, 2049, 2048, 2049, 2049, 2048], segments_sector_2=[2048, 2049, 2048, 2048, 2049, 2048, 2048], segments_sector_3=[2049, 2049, 2048, 2048, 2049, 2049, 2049, 2049, 2049], st_speed=345),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=23, lap_number=4, date_start='2025-09-07T13:07:59.210000+00:00', duration_sector_1=27.608, duration_sector_2=29.388, duration_sector_3=28.431, i1_speed=315, i2_speed=336, is_pit_out_lap=False, lap_duration=85.427, segments_sector_1=[None, 2048, 2048, 2049, 2049, 2048], segments_sector_2=[2049, 2049, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2049], st_speed=351),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=31, lap_number=4, date_start='2025-09-07T13:07:59.600000+00:00', duration_sector_1=27.582, duration_sector_2=29.397, duration_sector_3=28.456, i1_speed=317, i2_speed=337, is_pit_out_lap=False, lap_duration=85.435, segments_sector_1=[None, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2049, 2048, 2049, 2049, 2049], st_speed=329),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=30, lap_number=4, date_start='2025-09-07T13:07:59.913000+00:00', duration_sector_1=27.594, duration_sector_2=29.348, duration_sector_3=28.462, i1_speed=312, i2_speed=340, is_pit_out_lap=False, lap_duration=85.404, segments_sector_1=[None, 2049, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2049, 2048], segments_sector_3=[2048, 2048, 2051, 2048, 2048, 2049, 2049, 2049, 2049], st_speed=None),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=18, lap_number=4, date_start='2025-09-07T13:08:00.804000+00:00', duration_sector_1=27.515, duration_sector_2=29.373, duration_sector_3=28.321, i1_speed=314, i2_speed=334, is_pit_out_lap=False, lap_duration=85.209, segments_sector_1=[2048, 2048, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2049, 2048, 2049, 2048, 2048, 2049, 2049, 2049, 2049], st_speed=334),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=43, lap_number=4, date_start='2025-09-07T13:08:01.757000+00:00', duration_sector_1=27.363, duration_sector_2=29.501, duration_sector_3=28.176, i1_speed=311, i2_speed=329, is_pit_out_lap=False, lap_duration=85.04, segments_sector_1=[2048, 2048, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2049, 2049, 2049, 2048, 2049, 2048, 2049, 2049, 2049], st_speed=None),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=6, lap_number=4, date_start='2025-09-07T13:08:02.335000+00:00', duration_sector_1=27.616, duration_sector_2=29.235, duration_sector_3=28.367, i1_speed=321, i2_speed=341, is_pit_out_lap=False, lap_duration=85.218, segments_sector_1=[None, 2049, 2049, 2048, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2048, 2048, 2048, 2048], segments_sector_3=[2049, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=337),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=10, lap_number=4, date_start='2025-09-07T13:08:03.054000+00:00', duration_sector_1=27.402, duration_sector_2=29.516, duration_sector_3=28.402, i1_speed=316, i2_speed=331, is_pit_out_lap=False, lap_duration=85.32, segments_sector_1=[None, 2049, 2049, 2051, 2049, 2048], segments_sector_2=[2048, 2048, 2049, 2049, 2049, 2049, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=338),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=1, lap_number=5, date_start='2025-09-07T13:09:13.857000+00:00', duration_sector_1=27.52, duration_sector_2=28.427, duration_sector_3=27.641, i1_speed=309, i2_speed=310, is_pit_out_lap=False, lap_duration=83.588, segments_sector_1=[2048, 2048, 2048, 2051, 2048, 2048], segments_sector_2=[2048, 2051, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=317),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=4, lap_number=5, date_start='2025-09-07T13:09:14.966000+00:00', duration_sector_1=27.645, duration_sector_2=28.659, duration_sector_3=27.934, i1_speed=308, i2_speed=309, is_pit_out_lap=False, lap_duration=84.238, segments_sector_1=[None, 2049, 2048, 2049, 2049, 2048], segments_sector_2=[2048, 2049, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=316),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=16, lap_number=5, date_start='2025-09-07T13:09:18.122000+00:00', duration_sector_1=27.531, duration_sector_2=28.968, duration_sector_3=27.942, i1_speed=314, i2_speed=314, is_pit_out_lap=False, lap_duration=84.441, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2049, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=333),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=81, lap_number=5, date_start='2025-09-07T13:09:18.607000+00:00', duration_sector_1=27.39, duration_sector_2=28.967, duration_sector_3=28.001, i1_speed=315, i2_speed=322, is_pit_out_lap=False, lap_duration=84.358, segments_sector_1=[None, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2049], st_speed=333),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=63, lap_number=5, date_start='2025-09-07T13:09:19.201000+00:00', duration_sector_1=27.428, duration_sector_2=28.862, duration_sector_3=28.054, i1_speed=313, i2_speed=329, is_pit_out_lap=False, lap_duration=84.344, segments_sector_1=[2048, 2049, 2048, 2049, 2049, 2048], segments_sector_2=[2049, 2049, 2049, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2049, 2048, 2048, 2049, 2048, 2049], st_speed=337),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=5, lap_number=5, date_start='2025-09-07T13:09:20.281000+00:00', duration_sector_1=27.524, duration_sector_2=28.79, duration_sector_3=28.015, i1_speed=318, i2_speed=326, is_pit_out_lap=False, lap_duration=84.329, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2049, 2048, 2049, 2048, 2051, 2048, 2049], st_speed=330),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=14, lap_number=5, date_start='2025-09-07T13:09:21.132000+00:00', duration_sector_1=27.854, duration_sector_2=29.048, duration_sector_3=28.227, i1_speed=317, i2_speed=332, is_pit_out_lap=False, lap_duration=85.129, segments_sector_1=[2048, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2049, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2049, 2049, 2048, 2049, 2048, 2049], st_speed=351),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=44, lap_number=5, date_start='2025-09-07T13:09:21.584000+00:00', duration_sector_1=26.922, duration_sector_2=29.052, duration_sector_3=27.968, i1_speed=320, i2_speed=331, is_pit_out_lap=False, lap_duration=83.942, segments_sector_1=[2051, 2051, 2049, 2048, 2048, 2048], segments_sector_2=[2049, 2049, 2048, 2049, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2049, 2048, 2049, 2048, 2048], st_speed=363),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=22, lap_number=5, date_start='2025-09-07T13:09:22.294000+00:00', duration_sector_1=27.424, duration_sector_2=29.067, duration_sector_3=28.103, i1_speed=317, i2_speed=335, is_pit_out_lap=False, lap_duration=84.594, segments_sector_1=[2048, 2048, 2048, 2048, 2049, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2049, 2048, 2048, 2048, 2049, 2048, 2049], st_speed=341),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=12, lap_number=5, date_start='2025-09-07T13:09:22.763000+00:00', duration_sector_1=27.253, duration_sector_2=29.309, duration_sector_3=28.088, i1_speed=319, i2_speed=336, is_pit_out_lap=False, lap_duration=84.65, segments_sector_1=[None, 2049, 2049, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2049, 2049, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2049, 2048, 2048, 2048, 2048, 2048, 2049], st_speed=348),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=87, lap_number=5, date_start='2025-09-07T13:09:23.282000+00:00', duration_sector_1=27.591, duration_sector_2=29.143, duration_sector_3=28.095, i1_speed=319, i2_speed=338, is_pit_out_lap=False, lap_duration=84.829, segments_sector_1=[None, 2048, 2049, 2048, 2048, 2048], segments_sector_2=[2049, 2048, 2048, 2049, 2049, 2048, 2048], segments_sector_3=[2049, 2049, 2048, 2048, 2049, 2049, 2048, 2048, 2048], st_speed=331),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=55, lap_number=5, date_start='2025-09-07T13:09:23.977000+00:00', duration_sector_1=27.287, duration_sector_2=29.181, duration_sector_3=28.259, i1_speed=317, i2_speed=334, is_pit_out_lap=False, lap_duration=84.727, segments_sector_1=[None, 2048, 2049, 2049, 2048, 2048], segments_sector_2=[2049, 2048, 2048, 2049, 2049, 2049, 2048], segments_sector_3=[2049, 2049, 2049, 2048, 2048, 2048, 2048, 2048, 2049], st_speed=346),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=23, lap_number=5, date_start='2025-09-07T13:09:24.554000+00:00', duration_sector_1=27.17, duration_sector_2=29.072, duration_sector_3=28.356, i1_speed=317, i2_speed=340, is_pit_out_lap=False, lap_duration=84.598, segments_sector_1=[None, 2049, 2049, 2049, 2048, 2048], segments_sector_2=[2049, 2049, 2048, 2049, 2048, 2048, 2049], segments_sector_3=[2049, 2049, 2049, 2048, 2048, 2048, 2049, 2048, 2049], st_speed=356),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=31, lap_number=5, date_start='2025-09-07T13:09:25.055000+00:00', duration_sector_1=27.331, duration_sector_2=29.044, duration_sector_3=28.31, i1_speed=316, i2_speed=336, is_pit_out_lap=False, lap_duration=84.685, segments_sector_1=[None, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2049, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2048, 2048, 2049, 2048, 2049], st_speed=340),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=30, lap_number=5, date_start='2025-09-07T13:09:25.328000+00:00', duration_sector_1=27.397, duration_sector_2=29.118, duration_sector_3=28.313, i1_speed=317, i2_speed=340, is_pit_out_lap=False, lap_duration=84.828, segments_sector_1=[None, 2049, 2048, 2048, 2048, 2048], segments_sector_2=[2049, 2049, 2048, 2048, 2048, 2049, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2048, 2049, 2049, 2048, 2049], st_speed=334),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=18, lap_number=5, date_start='2025-09-07T13:09:25.878000+00:00', duration_sector_1=27.56, duration_sector_2=29.143, duration_sector_3=28.212, i1_speed=316, i2_speed=334, is_pit_out_lap=False, lap_duration=84.915, segments_sector_1=[2049, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2049, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2049, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=326),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=43, lap_number=5, date_start='2025-09-07T13:09:26.770000+00:00', duration_sector_1=27.726, duration_sector_2=28.972, duration_sector_3=28.247, i1_speed=310, i2_speed=330, is_pit_out_lap=False, lap_duration=84.945, segments_sector_1=[2049, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2049, 2049, 2048, 2048, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048, 2049], st_speed=333),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=6, lap_number=5, date_start='2025-09-07T13:09:27.428000+00:00', duration_sector_1=27.34, duration_sector_2=29.36, duration_sector_3=28.187, i1_speed=320, i2_speed=340, is_pit_out_lap=False, lap_duration=84.887, segments_sector_1=[2048, 2048, 2048, 2049, 2049, 2048], segments_sector_2=[2048, 2049, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2049, 2049, 2048, 2048, 2048, 2048, 2048, 2048, 2049], st_speed=333),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=10, lap_number=5, date_start='2025-09-07T13:09:28.307000+00:00', duration_sector_1=27.542, duration_sector_2=29.258, duration_sector_3=29.191, i1_speed=313, i2_speed=329, is_pit_out_lap=False, lap_duration=85.991, segments_sector_1=[2048, 2048, 2049, 2048, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2048, 2048, 2048], segments_sector_3=[2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=337),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=1, lap_number=6, date_start='2025-09-07T13:10:37.529000+00:00', duration_sector_1=27.434, duration_sector_2=28.496, duration_sector_3=27.646, i1_speed=311, i2_speed=312, is_pit_out_lap=False, lap_duration=83.576, segments_sector_1=[None, 2048, 2048, 2051, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=320),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=4, lap_number=6, date_start='2025-09-07T13:10:39.295000+00:00', duration_sector_1=27.407, duration_sector_2=28.595, duration_sector_3=27.885, i1_speed=309, i2_speed=311, is_pit_out_lap=False, lap_duration=83.887, segments_sector_1=[None, 2049, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=324),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=16, lap_number=6, date_start='2025-09-07T13:10:42.665000+00:00', duration_sector_1=27.986, duration_sector_2=28.969, duration_sector_3=27.903, i1_speed=320, i2_speed=325, is_pit_out_lap=False, lap_duration=84.858, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2049, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2051, 2048, 2048, 2048, 2049, 2048], st_speed=322),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=81, lap_number=6, date_start='2025-09-07T13:10:42.936000+00:00', duration_sector_1=27.322, duration_sector_2=28.515, duration_sector_3=27.842, i1_speed=319, i2_speed=311, is_pit_out_lap=False, lap_duration=83.679, segments_sector_1=[None, 2049, 2048, 2048, 2048, 2048], segments_sector_2=[2049, 2049, 2051, 2049, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2049, 2049, 2048, 2048, 2048], st_speed=353),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=63, lap_number=6, date_start='2025-09-07T13:10:43.620000+00:00', duration_sector_1=27.492, duration_sector_2=28.842, duration_sector_3=28.123, i1_speed=315, i2_speed=330, is_pit_out_lap=False, lap_duration=84.457, segments_sector_1=[2049, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2049, 2048, 2049, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=334),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=5, lap_number=6, date_start='2025-09-07T13:10:44.571000+00:00', duration_sector_1=27.473, duration_sector_2=28.841, duration_sector_3=28.288, i1_speed=None, i2_speed=334, is_pit_out_lap=False, lap_duration=84.602, segments_sector_1=[None, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2049, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=332),
# ...
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=10, lap_number=51, date_start='2025-09-07T14:14:20.889000+00:00', duration_sector_1=27.013, duration_sector_2=28.133, duration_sector_3=27.178, i1_speed=313, i2_speed=322, is_pit_out_lap=False, lap_duration=82.324, segments_sector_1=[2049, 2048, 2048, 2049, 2049, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2049, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2049, 2048, 2048, 2048], st_speed=331),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=18, lap_number=51, date_start='2025-09-07T14:14:24.530000+00:00', duration_sector_1=27.07, duration_sector_2=27.867, duration_sector_3=27.227, i1_speed=313, i2_speed=317, is_pit_out_lap=False, lap_duration=82.164, segments_sector_1=[2048, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2049, 2049, 2049, 2048, 2048], segments_sector_3=[2049, 2048, 2048, 2048, 2049, 2049, 2049, 2049, 2049], st_speed=326),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=4, lap_number=52, date_start='2025-09-07T14:14:36.655000+00:00', duration_sector_1=27.019, duration_sector_2=27.406, duration_sector_3=26.834, i1_speed=None, i2_speed=313, is_pit_out_lap=False, lap_duration=81.259, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2049, 2048], segments_sector_3=[2049, 2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048], st_speed=None),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=81, lap_number=52, date_start='2025-09-07T14:14:38.124000+00:00', duration_sector_1=26.885, duration_sector_2=27.534, duration_sector_3=26.967, i1_speed=320, i2_speed=321, is_pit_out_lap=False, lap_duration=81.386, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048], st_speed=341),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=16, lap_number=52, date_start='2025-09-07T14:14:41.874000+00:00', duration_sector_1=27.031, duration_sector_2=27.73, duration_sector_3=27.152, i1_speed=322, i2_speed=324, is_pit_out_lap=False, lap_duration=81.913, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2049, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048], st_speed=329),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=63, lap_number=52, date_start='2025-09-07T14:14:48.483000+00:00', duration_sector_1=27.131, duration_sector_2=27.796, duration_sector_3=27.145, i1_speed=316, i2_speed=318, is_pit_out_lap=False, lap_duration=82.072, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=337),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=44, lap_number=52, date_start='2025-09-07T14:14:53.491000+00:00', duration_sector_1=26.905, duration_sector_2=27.793, duration_sector_3=27.045, i1_speed=323, i2_speed=325, is_pit_out_lap=False, lap_duration=81.743, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=330),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=23, lap_number=52, date_start='2025-09-07T14:15:06.696000+00:00', duration_sector_1=26.8, duration_sector_2=27.909, duration_sector_3=27.139, i1_speed=311, i2_speed=313, is_pit_out_lap=False, lap_duration=81.848, segments_sector_1=[None, 2048, 2049, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2049, 2049, 2048, 2048, 2048], st_speed=349),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=12, lap_number=52, date_start='2025-09-07T14:15:10.168000+00:00', duration_sector_1=27.047, duration_sector_2=27.979, duration_sector_3=27.082, i1_speed=324, i2_speed=322, is_pit_out_lap=False, lap_duration=82.108, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=341),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=31, lap_number=52, date_start='2025-09-07T14:15:10.936000+00:00', duration_sector_1=54.612, duration_sector_2=28.306, duration_sector_3=27.807, i1_speed=283, i2_speed=329, is_pit_out_lap=True, lap_duration=110.725, segments_sector_1=[2064, 2064, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2049, 2049, 2048], segments_sector_3=[2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=288),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=5, lap_number=52, date_start='2025-09-07T14:15:13.082000+00:00', duration_sector_1=27.274, duration_sector_2=28.131, duration_sector_3=27.214, i1_speed=315, i2_speed=322, is_pit_out_lap=False, lap_duration=82.619, segments_sector_1=[None, 2048, 2049, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=328),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=6, lap_number=52, date_start='2025-09-07T14:15:18.729000+00:00', duration_sector_1=27.238, duration_sector_2=27.877, duration_sector_3=27.1, i1_speed=317, i2_speed=320, is_pit_out_lap=False, lap_duration=82.215, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2048, 2048, 2049, 2048, 2048], st_speed=326),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=55, lap_number=52, date_start='2025-09-07T14:15:19.566000+00:00', duration_sector_1=27.123, duration_sector_2=27.863, duration_sector_3=27.062, i1_speed=318, i2_speed=328, is_pit_out_lap=False, lap_duration=82.048, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2049, 2049, 2048, 2048, 2048, 2048, 2048], st_speed=338),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=87, lap_number=52, date_start='2025-09-07T14:15:24.834000+00:00', duration_sector_1=27.198, duration_sector_2=27.797, duration_sector_3=27.164, i1_speed=None, i2_speed=319, is_pit_out_lap=False, lap_duration=82.159, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2049, 2048, 2049, 2049, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2049, 2048, 2048, 2048, 2048], st_speed=324),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=22, lap_number=52, date_start='2025-09-07T14:15:34.411000+00:00', duration_sector_1=27.316, duration_sector_2=28.073, duration_sector_3=27.323, i1_speed=315, i2_speed=319, is_pit_out_lap=False, lap_duration=82.712, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2049, 2048, 2049, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=319),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=30, lap_number=52, date_start='2025-09-07T14:15:35.395000+00:00', duration_sector_1=27.14, duration_sector_2=28.372, duration_sector_3=27.402, i1_speed=None, i2_speed=324, is_pit_out_lap=False, lap_duration=82.914, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2048, 2049, 2048, 2048, 2048], st_speed=334),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=1, lap_number=53, date_start='2025-09-07T14:15:38.620000+00:00', duration_sector_1=26.987, duration_sector_2=27.527, duration_sector_3=26.586, i1_speed=320, i2_speed=322, is_pit_out_lap=False, lap_duration=81.1, segments_sector_1=[2049, 2048, 2048, 2048, 2049, 2049], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2051, 2048], segments_sector_3=[2048, 2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048], st_speed=329),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=10, lap_number=52, date_start='2025-09-07T14:15:43.136000+00:00', duration_sector_1=27.293, duration_sector_2=27.771, duration_sector_3=27.121, i1_speed=309, i2_speed=314, is_pit_out_lap=False, lap_duration=82.185, segments_sector_1=[2048, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2049, 2049, 2049, 2049, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2048, 2049, 2048, 2048, 2048, 2048], st_speed=316),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=43, lap_number=52, date_start='2025-09-07T14:15:44.292000+00:00', duration_sector_1=27.363, duration_sector_2=28.096, duration_sector_3=27.265, i1_speed=314, i2_speed=318, is_pit_out_lap=False, lap_duration=82.724, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=323),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=18, lap_number=52, date_start='2025-09-07T14:15:46.553000+00:00', duration_sector_1=27.127, duration_sector_2=27.768, duration_sector_3=27.387, i1_speed=314, i2_speed=330, is_pit_out_lap=False, lap_duration=82.282, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2049, 2048], segments_sector_3=[2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=325),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=4, lap_number=53, date_start='2025-09-07T14:15:57.846000+00:00', duration_sector_1=26.81, duration_sector_2=27.381, duration_sector_3=26.71, i1_speed=311, i2_speed=318, is_pit_out_lap=False, lap_duration=80.901, segments_sector_1=[None, 2048, 2048, 2048, 2049, 2048], segments_sector_2=[2049, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048], st_speed=336),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=81, lap_number=53, date_start='2025-09-07T14:15:59.565000+00:00', duration_sector_1=26.867, duration_sector_2=27.52, duration_sector_3=26.984, i1_speed=316, i2_speed=319, is_pit_out_lap=False, lap_duration=81.371, segments_sector_1=[None, 2048, 2048, 2048, 2049, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=333),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=16, lap_number=53, date_start='2025-09-07T14:16:03.877000+00:00', duration_sector_1=26.839, duration_sector_2=27.546, duration_sector_3=26.909, i1_speed=327, i2_speed=329, is_pit_out_lap=False, lap_duration=81.294, segments_sector_1=[None, 2048, 2048, 2048, 2049, 2048], segments_sector_2=[2049, 2048, 2048, 2048, 2049, 2049, 2048], segments_sector_3=[2049, 2048, 2049, 2049, 2048, 2048, 2048, 2048, 2048], st_speed=332),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=63, lap_number=53, date_start='2025-09-07T14:16:10.440000+00:00', duration_sector_1=27.146, duration_sector_2=27.761, duration_sector_3=26.981, i1_speed=315, i2_speed=327, is_pit_out_lap=False, lap_duration=81.888, segments_sector_1=[None, 2048, 2048, 2048, 2049, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2049, 2048], segments_sector_3=[2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=328),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=44, lap_number=53, date_start='2025-09-07T14:16:15.127000+00:00', duration_sector_1=26.838, duration_sector_2=27.827, duration_sector_3=27.192, i1_speed=322, i2_speed=324, is_pit_out_lap=False, lap_duration=81.857, segments_sector_1=[None, 2048, 2048, 2048, 2049, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=329),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=23, lap_number=53, date_start='2025-09-07T14:16:28.744000+00:00', duration_sector_1=26.863, duration_sector_2=27.678, duration_sector_3=26.827, i1_speed=315, i2_speed=315, is_pit_out_lap=False, lap_duration=81.368, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2049, 2048, 2048, 2048], segments_sector_3=[2048, 2049, 2048, 2049, 2049, 2049, 2049, 2048, 2048], st_speed=338),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=12, lap_number=53, date_start='2025-09-07T14:16:32.359000+00:00', duration_sector_1=27.095, duration_sector_2=27.877, duration_sector_3=26.996, i1_speed=316, i2_speed=317, is_pit_out_lap=False, lap_duration=81.968, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2049, 2049, 2048], segments_sector_3=[2048, 2049, 2049, 2049, 2048, 2048, 2048, 2048, 2048], st_speed=332),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=5, lap_number=53, date_start='2025-09-07T14:16:35.569000+00:00', duration_sector_1=27.042, duration_sector_2=28.042, duration_sector_3=27.236, i1_speed=321, i2_speed=325, is_pit_out_lap=False, lap_duration=82.32, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2049, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=327),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=6, lap_number=53, date_start='2025-09-07T14:16:40.852000+00:00', duration_sector_1=27.306, duration_sector_2=28.104, duration_sector_3=27.126, i1_speed=None, i2_speed=322, is_pit_out_lap=False, lap_duration=82.536, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2051, 2048, 2048, 2048, 2048, 2048], st_speed=340),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=55, lap_number=53, date_start='2025-09-07T14:16:41.623000+00:00', duration_sector_1=27.146, duration_sector_2=28.159, duration_sector_3=27.077, i1_speed=317, i2_speed=328, is_pit_out_lap=False, lap_duration=82.382, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2049, 2049, 2048, 2049, 2048, 2049, 2048], st_speed=339),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=87, lap_number=53, date_start='2025-09-07T14:16:47.003000+00:00', duration_sector_1=27.055, duration_sector_2=27.796, duration_sector_3=26.969, i1_speed=316, i2_speed=329, is_pit_out_lap=False, lap_duration=81.82, segments_sector_1=[None, 2048, 2048, 2049, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2049, 2048], segments_sector_3=[2051, 2049, 2048, 2049, 2048, 2048, 2048, 2048, 2048], st_speed=323),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=22, lap_number=53, date_start='2025-09-07T14:16:56.981000+00:00', duration_sector_1=27.413, duration_sector_2=28.264, duration_sector_3=27.448, i1_speed=314, i2_speed=315, is_pit_out_lap=False, lap_duration=83.125, segments_sector_1=[None, 2048, 2048, 2048, 2049, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2048, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=318),
#  F1Lap(meeting_key=1268, session_key=9912, driver_number=30, lap_number=53, date_start='2025-09-07T14:16:58.295000+00:00', duration_sector_1=27.364, duration_sector_2=28.439, duration_sector_3=27.82, i1_speed=None, i2_speed=321, is_pit_out_lap=False, lap_duration=83.623, segments_sector_1=[None, 2048, 2048, 2048, 2048, 2048], segments_sector_2=[2048, 2048, 2048, 2048, 2049, 2048, 2048], segments_sector_3=[2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048], st_speed=322)]

# %%
# Example usage of the new F1Lap data type
laps = get_laps(driver_number=63)  # Get laps for driver #63

if laps:
    print(f"\nTotal laps: {len(laps)}")
    
    # Example: Get complete laps only
    complete_laps = [lap for lap in laps if lap.is_complete_lap()]
    print(f"Complete laps: {len(complete_laps)}")
    
    # Example: Get fastest lap
    fastest_lap = min([lap for lap in laps if lap.lap_duration], key=lambda x: x.lap_duration)
    print(f"Fastest lap: {fastest_lap}")
    
    # Example: Analyze sector times
    if complete_laps:
        first_complete_lap = complete_laps[0]
        sector_times = first_complete_lap.get_sector_times()
        speeds = first_complete_lap.get_speeds()
        avg_speed = first_complete_lap.get_average_speed()
        
        print(f"\nFirst complete lap analysis:")
        print(f"  Lap time: {first_complete_lap.get_total_lap_time():.3f}s")
        print(f"  Sector 1: {sector_times[0]:.3f}s")
        print(f"  Sector 2: {sector_times[1]:.3f}s") 
        print(f"  Sector 3: {sector_times[2]:.3f}s")
        print(f"  I1 Speed: {speeds[0]} km/h")
        print(f"  I2 Speed: {speeds[1]} km/h")
        print(f"  ST Speed: {speeds[2]} km/h")
        print(f"  Average Speed: {avg_speed:.1f} km/h" if avg_speed else "  Average Speed: N/A")
    
    # Example: Get lap start times
    laps_with_times = [lap for lap in laps if lap.date_start]
    if laps_with_times:
        print(f"\nLaps with start times: {len(laps_with_times)}")
        for lap in laps_with_times[:3]:
            start_time = lap.get_start_datetime()
            print(f"  Lap {lap.lap_number}: {start_time}")
# Out:
# Retrieved 53 laps for session latest
#   - Lap #1 - Driver #63 - N/A
#   - Lap #2 - Driver #63 - 85.309s
#   - Lap #3 - Driver #63 - 85.346s
#   ... and 50 more laps
#
# Total laps: 53
# Complete laps: 52
# Fastest lap: Lap #45 - Driver #63 - 81.800s
#
# First complete lap analysis:
#   Lap time: 85.309s
#   Sector 1: 27.677s
#   Sector 2: 29.339s
#   Sector 3: 28.293s
#   I1 Speed: 321 km/h
#   I2 Speed: 334 km/h
#   ST Speed: 338 km/h
#   Average Speed: 331.0 km/h
#
# Laps with start times: 52
#   Lap 2: 2025-09-07 13:05:04.066000+00:00
#   Lap 3: 2025-09-07 13:06:29.443000+00:00
#   Lap 4: 2025-09-07 13:07:54.757000+00:00
